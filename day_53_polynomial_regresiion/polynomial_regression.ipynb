# %%
import numpy as np
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression,SGDClassifier
from sklearn.preprocessing import PolynomialFeatures,StandardScaler
from sklearn.model_selection import train_test_split

# %%
X = 6 * np.random.rand(200, 1) - 3
y = 0.8 * X**2 + 0.9 * X + 2 + np.random.randn(200, 1)
# y = 0.8x^2 + 0.9x + 2

# %%
plt.plot(X,y,'b .')
plt.xlabel('X')
plt.ylabel('y')
plt.show()
# Out:
# 2.984466329774029

# %%
# Train test split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)
print(X_train.shape," ",y_train.shape)
# Out:
# (160, 1)   (160, 1)

# %%
lr= LinearRegression()
lr.fit(X_train,y_train)
y_pred = lr.predict(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.3478747453408053

# %%
plt.plot(X_train,lr.predict(X_train),color='r')
plt.plot(X, y, "b.")
plt.xlabel("X")
plt.ylabel("y")
plt.show()

# %% [markdown]
# ## Applying Polynomial Linear Regression

# %%
poly = PolynomialFeatures(degree=2,include_bias=True)

X_train_trans = poly.fit_transform(X_train)
X_test_trans = poly.transform(X_test)
X_train_trans.shape
# Out:
# (160, 3)

# %%
lr= LinearRegression()
lr.fit(X_train_trans,y_train)
y_pred = lr.predict(X_test_trans)
r2_score(y_test,y_pred)
# Out:
# 0.9123959373559014

# %%
X_train_trans[0]
# Out:
# array([1.        , 2.79445653, 7.80898727])

# %%
X_new=np.linspace(-3, 3, 200).reshape(200, 1)
X_new_poly = poly.transform(X_new)
y_new = lr.predict(X_new_poly)

# %%
X_new_poly[:5]

X_new_data=np.linspace(-3.5,3.5,200).reshape(200,1)
X_new_data_poly = poly.transform(X_new_data)
y_new_data = lr.predict(X_new_data_poly)

# %%
plt.plot(X_new_data, y_new_data, "r-", linewidth=2, label="Predictions")
plt.plot(X_train, y_train, "b.",label='Training points')
plt.plot(X_test, y_test, "g.",label='Testing points')
plt.xlabel("X")
plt.ylabel("y")
plt.legend()
plt.show()

# %%
plt.plot(X_new, y_new, "r-", linewidth=2, label="Predictions")
plt.plot(X_train, y_train, "b.",label='Training points')
plt.plot(X_test, y_test, "g.",label='Testing points')
plt.xlabel("X")
plt.ylabel("y")
plt.legend()
plt.show()

# %%
# plt.plot(X_train,lr.predict(X_train_trans),color='r')
# #plt.plot(X_train, X_test, "b.")
# plt.xlabel("X")
# plt.ylabel("y")
# plt.show()
